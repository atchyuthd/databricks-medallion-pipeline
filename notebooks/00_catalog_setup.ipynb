# %%
# %run ../conf/config

# %% [markdown]
# %md
# # Setup: Catalog and Storage
#
# Creates the Unity Catalog objects the pipeline depends on. Idempotent —
# safe to re-run, and required once per target catalog before any other notebook.
#
# **Creates**
# - Catalog `{CATALOG}`
# - Schemas `bronze`, `silver`, `gold`, `source_data`
# - Volume `source_data.raw` and its per-entity folder skeleton
#
# **Outputs:** empty schemas and an empty raw volume
# **Depends on:** `conf/config`
#
# Run `01_load_sample_data` next to populate the volume.

# %%
spark.sql(f"CREATE CATALOG IF NOT EXISTS {CATALOG}")

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {BRONZE}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {SILVER}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {GOLD}")

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.source_data")
spark.sql(f"CREATE VOLUME IF NOT EXISTS {CATALOG}.source_data.raw")

# %%
for folder in ["brands", "category", "products", "customers", "date", "order_items/landing"]:
    dbutils.fs.mkdirs(f"{RAW_ROOT}/{folder}")
